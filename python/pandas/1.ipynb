# %%
import pandas as pd
values=[10,20,30,40,50]
y=pd.Series(values)
x=pd.Series(values,index=['a','a','c','d','a'])
print(x)
print(y)
# Out:
# a    10
# a    20
# c    30
# d    40
# a    50
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
def space():
    print("-"*20)

# %%
# duplicate
x.loc['a']#by using the index we can easily access the value in the x
# Out:
# a    10
# a    20
# a    50
# dtype: int64

# %%
# dataframe
df=pd.DataFrame({
    'name':['milke','ti','sam'],
    'age':[12,14,54],
    'comapany':['ama','flip','colab']
})
df
# Out:
#     name  age comapany
# 0  milke   12      ama
# 1     ti   14     flip
# 2    sam   54    colab

# %%
dg=df.set_index('name')
print(dg)
space()
print(df.columns)
# Out:
#        age comapany
# name
# milke   12      ama
# ti      14     flip
# sam     54    colab
# --------------------
# Index(['name', 'age', 'comapany'], dtype='object')

# %%
df1=pd.DataFrame({
    'a':[1,2,3]
})
df2=pd.DataFrame({
    'a':[10,20,30]
})
df1+df2
# Out:
#     a
# 0  11
# 1  22
# 2  33

# %%
df1=pd.DataFrame({
    'a':[1,2,3]
},index=[0,1,2])
df2=pd.DataFrame({
    'a':[10,20,30]
},index=[1,2,0])
df1+df2#the same index only get add togeather
# Out:
#     a
# 0  31
# 1  12
# 2  23

# %%
df1=pd.DataFrame({
    'a':[1,2,3]
})
df2=pd.DataFrame({
    'a':[10,20,30,40]
})
df1+df2
# Out:
#       a
# 0  11.0
# 1  22.0
# 2  33.0
# 3   NaN

# %%
df1=pd.DataFrame({
    'a':[1,2,3]
},index=[1,2,3])
df2=pd.DataFrame({
    'a':[10,20,30,40]
},index=[1,2,3,4])
df1+df2
# Out:
#       a
# 1  11.0
# 2  22.0
# 3  33.0
# 4   NaN

# %%
df1=pd.DataFrame({
    'a':[1,2,3]
},index=[1,2,3])
df2=pd.DataFrame({
    'a':[10,20,30]
},index=[4,5,6])
df1+df2
# Out:
#     a
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN

# %%
df
# Out:
#     name  age comapany
# 0  milke   12      ama
# 1     ti   14     flip
# 2    sam   54    colab

# %%
df=df.reset_index()

# %%
df
# Out:
#    index   name  age comapany
# 0      0  milke   12      ama
# 1      1     ti   14     flip
# 2      2    sam   54    colab

# %%
df.to_csv('mydata.csv')#just type df.to_ -->and from here you can choose the format you want

# %%
b=pd.read_csv("mydata.csv")
b
# Out:
#    Unnamed: 0  index   name  age comapany
# 0           0      0  milke   12      ama
# 1           1      1     ti   14     flip
# 2           2      2    sam   54    colab

# %%
c=pd.read_csv("mydata.csv",index_col=0)#this index_column tells that the first column of the file is indeed the first column
c
# Out:
#    index   name  age comapany
# 0      0  milke   12      ama
# 1      1     ti   14     flip
# 2      2    sam   54    colab

# %%
# to export your data without the index to any file foramte
# for ex take csv
df.to_csv("hey_csv.csv",index=None)

# %%
df.to_json("file.json")

# %%
df.to_dict()
# Out:
# {'index': {0: 0, 1: 1, 2: 2},
#  'name': {0: 'milke', 1: 'ti', 2: 'sam'},
#  'age': {0: 12, 1: 14, 2: 54},
#  'comapany': {0: 'ama', 1: 'flip', 2: 'colab'}}
