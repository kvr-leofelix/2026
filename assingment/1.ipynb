# %%
import random
h = []
t = []
for i in range(50):
    a = random.randint(0,2)
    if a == 0:
        h.append(a)
    else:
        t.append(a)
print(f'TOTAL HEAD {len(h)}')
print(f'TOTAL TAIL {len(t)}')
# Out:
# TOTAL HEAD 16
# TOTAL TAIL 34

# %%
m =  [12, 15, 18, 20, 25]
mean = sum(m)/len(m)
# print(mean:.2f) TODO: THIS WILL NOT WORK 
print(f'ans {mean:.2f}')
# Out:
# ans 18.00

# %%
import random
q = []
for i in range(100):
    p = random.randint(1,7)
    q.append(p)

for j in range(1,7):
    print(f'number of dice it gives {j} is {q.count(j)} and its empiriral prob is {q.count(j)/100}')
# Out:
# number of dice it gives 1 is 11 and its empiriral prob is 0.11
# number of dice it gives 2 is 15 and its empiriral prob is 0.15
# number of dice it gives 3 is 19 and its empiriral prob is 0.19
# number of dice it gives 4 is 17 and its empiriral prob is 0.17
# number of dice it gives 5 is 16 and its empiriral prob is 0.16
# number of dice it gives 6 is 12 and its empiriral prob is 0.12

# %%
import random
# 0 is T and 1 is head
y=[]
for x in range(30):
    v = 0
    while True:
        w = random.randint(0,2)
        if w == 1:
           break
        v += 1
    y.append(v)
# print(v)
print("the list",y)
z = sum(y)/len(y)
print("avg",z)
print("max",max(y))
# Out:
# the list [0, 0, 0, 4, 3, 2, 0, 1, 4, 1, 0, 2, 0, 2, 0, 1, 0, 0, 9, 1, 4, 1, 0, 0, 3, 0, 0, 7, 0, 1]
# avg 1.5333333333333334
# max 9
