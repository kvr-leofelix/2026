# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
# %time
# %pwd
df = pd.read_csv("insurance_data.csv")
# Out:
# CPU times: total: 0 ns
# Wall time: 5.96 μs

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.9,random_state=9)

# %%
X_test
# Out:
#     age
# 5    56
# 9    61
# 15   55

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print("prediction",model.predict(X_test))
# Out:
# prediction [1 1 1]

# %%
print("accuracy",model.score(X_test,y_test))
# Out:
# accuracy 1.0

# %%
print(df[['age']])
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23
