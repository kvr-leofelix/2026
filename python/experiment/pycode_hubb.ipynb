# %%
from turtle import*
import colorsys
speed(0)
bgcolor("black")
h=0
for i in range(7):
    for j in range(14):
        c=colorsys.hsv_to_rgb(h,h,1)
        color(c)
        h+=0.02
        rt(90)
        circle(150-j*6,90)
        lt(90)
        circle(150-j*6,90)
        rt(90)
        circle(40,24)
done()
# Out:
# ---------------------------------------------------------------------------
# TurtleGraphicsError                       Traceback (most recent call last)
# Cell In[18], line 9
#       7 for j in range(14):
#       8     c=colorsys.hsv_to_rgb(h,h,1)
# ----> 9     color(c)
#      10     h+=0.02
#      11     rt(90)
#
# File <string>:8, in color(*args)
#
# File c:\Users\rasto\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2214, in TPen.color(self, *args)
#    2212 elif l == 3:
#    2213     pcolor = fcolor = args
# -> 2214 pcolor = self._colorstr(pcolor)
#    2215 fcolor = self._colorstr(fcolor)
#    2216 self.pen(pencolor=pcolor, fillcolor=fcolor)
#
# File c:\Users\rasto\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2703, in RawTurtle._colorstr(self, args)
#    2702 def _colorstr(self, args):
# -> 2703     return self.screen._colorstr(args)
#
# File c:\Users\rasto\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1157, in TurtleScreen._colorstr(self, color)
# ...
