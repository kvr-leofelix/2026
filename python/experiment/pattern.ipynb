# %%
n=5
for i in range(1,n+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(1,n+1):
    print(" "*(n-i)+"*"*(2*i-1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
text="hellokitty"
reverse_text=""
for char in text:
    reverse_text=char+reverse_text
print(reverse_text)
# Out:
# yttikolleh

# %%
text="hellokitty"
print(text[::-1])
# Out:
# yttikolleh

# %%
print(True+False+True)
# Out:
# 2
# 2

# %%
pee={"a":1,"b":2,"c":3}
print(pee.get("c"))
print(pee.keys())
print(pee.values())
print(pee.items)
# Out:
# 3
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])

# %%
a=3.6789
print(f"{a:.2f}")
print(format(a,".2f"))
# Out:
# 3.68
# 3.68

# %%
n=27
print(hex(n))
print(oct(n))
print(bin(n))
# Out:
# 0x1b
# 0o33
# 0b11011

# %%
print(divmod(20,5))
print(divmod(10,3))
# Out:
# (4, 0)
# (3, 1)

# %%
print(abs(-19))
# Out:
# 19

# %%
a=" hello bound"
print(a.upper())
print(a.strip())
# Out:
#  HELLO BOUND
# hello bound

# %%
a="booky trap"
print(a.find("tr"))
# Out:
# 6

# %%
text="a,b,c"
print(text.split(","))
word=['a', 'b', 'c']
print(",".join(word))
# Out:
# ['a', 'b', 'c']
# a,b,c

# %%
a=[6,87,9,8]
print(max(a),min(a))
# print(a.max(),a.min()) THIS DOSN'T EXIST
# Out:
# 87 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 a=[6,87,9,8]
#       2 print(max(a),min(a))
# ----> 3 print(a.max(),a.min())
#
# AttributeError: 'list' object has no attribute 'max'
