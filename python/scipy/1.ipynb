# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# basic optimization

# %%
from scipy.optimize import minimize

# %%
def f(x):
    return (x-3)**2
# for f(x)=(x-3)**3

res=minimize(f,2)#here 2 is pre initial guess
# note here f!=0 but close to zero by 10^-16 to 10^-17 times because of floating point precision
# jac:it is the slope
# njev:number of times the calulation happen to find the slope
# x: where they gonna have the lowest point

# %%
res
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 5.551437397369767e-17
#         x: [ 3.000e+00]
#       nit: 2
#       jac: [-4.325e-13]
#  hess_inv: [[ 5.000e-01]]
#      nfev: 6
#      njev: 3

# %%
res.x
# Out:
# array([2.99999999])

# %% [markdown]
# minimize f(x,y)=(x-1)**2+(y-2.5)**2
# constrain:
# x-2y+2>=0
# -x-2y+6>=0
# -x+2y+2>=0
# x>=0
# y>=0

# %%
f= lambda x:(x[0]-1)**2+(x[1]-2.5)**2
f([1,2])
# NOTE here x is vector having two element 
# treat x[0] as x and x[1] as y
# Out:
# 0.25

# %%
cons=({'type':'ineq','fun':lambda x:x[0]-2*x[1]+2},
      {'type':'ineq','fun':lambda x:-x[0]-2*x[1]+6},
      {'type':'ineq','fun':lambda x:-x[0]+2*x[1]+2},
      {'type':'ineq','fun':lambda x:x[0]},
      {'type':'ineq','fun':lambda x:x[1]}
      )
bnds=((0,None),(0,None))#None mean unbounded mean x goes to 0 to infinity and same with y
